# %% [markdown]
# <a href="https://colab.research.google.com/github/debug-phantom/CCMACLRN-ACTIVITIES/blob/main/Exercise%202B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2 B

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
import statsmodels.api as sm

# %%
df = pd.read_excel('traveldata.xlsx')

# %%
df

# %% [markdown]
# ## A. Correlation

# %% [markdown]
# ### Check the relationships between each independent variable and the dependent variable using scatterplots and correlations.

# %% [markdown]
# 1. Create scatter plot between miles traveled and travel time

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Miles Traveled', y='Travel Time', data=df)
plt.title('Scatter Plot of Miles Traveled vs Travel Time')
plt.xlabel('Miles Traveled')
plt.ylabel('Travel Time')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Create scatter plot between number of deliveries and travel time

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Number of Deliveries', y='Travel Time', data=df)
plt.title('Scatter Plot of Number of Deliveries vs Travel Time')
plt.xlabel('Number of Deliveries')
plt.ylabel('Travel Time')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. Create scatter plot between Gas Price and Travel time

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Gas Price', y='Travel Time', data=df)
plt.title('Scatter Plot of Gas Price vs Travel Time')
plt.xlabel('Gas Price')
plt.ylabel('Travel Time')
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Create a pairplot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# 5. Calculate pearson's correlation coefficient and p-value between Miles Traveled and Travel Time

# %%
r, p_value = pearsonr(df['Miles Traveled'], df['Travel Time'])
print(f"Pearson correlation coefficient: {r:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.9282
# P-value: 0.0001

# %% [markdown]
# 6. Calculate pearson's correlation coefficient and p-value between Number of Deliveries and Travel Time

# %%
r, p_value = pearsonr(df['Number of Deliveries'], df['Travel Time'])
print(f"Pearson correlation coefficient: {r:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.9164
# P-value: 0.0002

# %% [markdown]
# 7. Calculate pearson's correlation coefficient and p-value between Gas Price and Travel Time

# %%
r, p_value = pearsonr(df['Gas Price'], df['Travel Time'])
print(f"Pearson correlation coefficient: {r:.4f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Pearson correlation coefficient: 0.2672
# P-value: 0.4555

# %% [markdown]
# ### Check the relationships among the independent variables using scatterplots and correlations.

# %% [markdown]
# 8. Create scatter plot between Miles Traveled and Number of Deliveries.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Miles Traveled', y='Number of Deliveries', data=df)
plt.title('Scatter Plot of Miles Traveled vs Number of Deliveries')
plt.xlabel('Miles Traveled')
plt.ylabel('Number of Deliveries')
plt.grid(True)
plt.show()

# %% [markdown]
# 9. Create scatter plot between Miles traveled and Gas Price

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Miles Traveled', y='Gas Price', data=df)
plt.title('Scatter Plot of Miles Traveled vs Gas Price')
plt.xlabel('Miles Traveled')
plt.ylabel('Gas Price')
plt.grid(True)
plt.show()

# %% [markdown]
# 10. Create scatter plot between Number of Deliveries and Gas Price

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Number of Deliveries', y='Gas Price', data=df)
plt.title('Scatter Plot of Number of Deliveries vs Gas Price')
plt.xlabel('Number of Deliveries')
plt.ylabel('Gas Price')
plt.grid(True)
plt.show()

# %% [markdown]
# 11. Calculate pearson's correlation coefficient and p-value between Miles Traveled and Number of Deliveries

# %%
r, p_value = pearsonr(df['Miles Traveled'], df['Number of Deliveries'])
r_squared = r**2
print(f"R-squared between Miles Traveled and Number of Deliveries: {r_squared:.4f}")
print(f"P-value between Miles Traveled and Number of Deliveries: {p_value:.4f}")
# Out:
# R-squared between Miles Traveled and Number of Deliveries: 0.9137
# P-value between Miles Traveled and Number of Deliveries: 0.0000

# %% [markdown]
# 12. Calculate pearson's correlation coefficient and p-value between Miles Traveled and Gas Price

# %%
r, p_value = pearsonr(df['Miles Traveled'], df['Gas Price'])
r_squared = r**2
print(f"R-squared between Miles Traveled and Gas Price: {r_squared:.4f}")
print(f"P-value between Miles Traveled and Gas Price: {p_value:.4f}")
# Out:
# R-squared between Miles Traveled and Gas Price: 0.1266
# P-value between Miles Traveled and Gas Price: 0.3130

# %% [markdown]
# 13. Calculate pearson's correlation coefficient and p-value between Number of Deliveries and Gas Price

# %%
r, p_value = pearsonr(df['Number of Deliveries'], df['Gas Price'])
r_squared = r**2
print(f"R-squared between Number of Deliveries and Gas Price: {r_squared:.4f}")
print(f"P-value between Number of Deliveries and Gas Price: {p_value:.4f}")
# Out:
# R-squared between Number of Deliveries and Gas Price: 0.2482
# P-value between Number of Deliveries and Gas Price: 0.1427

# %% [markdown]
# ### Correlation Summary

# %% [markdown]
# 14. Create the correlation summary

# %%
correlation_matrix = df.corr()
display(correlation_matrix)
# Out:
#                       Miles Traveled  Number of Deliveries  Gas Price  \
# Miles Traveled              1.000000              0.955898   0.355796
# Number of Deliveries        0.955898              1.000000   0.498242
# Gas Price                   0.355796              0.498242   1.000000
# Travel Time                 0.928179              0.916443   0.267212
#
#                       Travel Time
# Miles Traveled           0.928179
# Number of Deliveries     0.916443
# Gas Price                0.267212
# Travel Time              1.000000

# %% [markdown]
# 15. Create a correlation matrix

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Building Different Regression Models

# %% [markdown]
# Find the best regression model

# %% [markdown]
# 16. Set independent and dependent variables

# %%
X = df[['Miles Traveled', 'Number of Deliveries', 'Gas Price']]
y = df['Travel Time']

# %% [markdown]
# 17. Build and train the model

# %%
X = sm.add_constant(X) # Add a constant to the independent variables
model = sm.OLS(y, X).fit() # Build and train the OLS model

# %% [markdown]
# 18. Display the statistical summary

# %%
display(model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Travel Time   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     16.99
# Date:                Fri, 29 Aug 2025   Prob (F-statistic):            0.00245
# Time:                        06:55:45   Log-Likelihood:               -0.98426
# No. Observations:                  10   AIC:                             9.969
# Df Residuals:                       6   BIC:                             11.18
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# 19. Display the $R^2$

# %%
print(f"R-squared of the model: {model.rsquared:.4f}")
# Out:
# R-squared of the model: 0.8947
